# %% [markdown]
# # VQA2.0 dataset visualisation
#
# This notebook documents how to create the data for VQA2.0 data visualization.
#
# The graph is plotted using Excel, the graphs are documented in `dataset_visualization.xlsx`.
#
# prerequisite: The below four files should exists
# * VQA2/v2_OpenEnded_mscoco_train2014_questions.json
# * VQA2/v2_OpenEnded_mscoco_val2014_questions.json
# * VQA2/v2_mscoco_train2014_annotations.json
# * VQA2/v2_mscoco_val2014_annotations.json
#
# They can be downloaded from the below sites respectively
# * https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/v2_Questions_Train_mscoco.zip
# * https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/v2_Questions_Val_mscoco.zip
# * https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/v2_Annotations_Train_mscoco.zip
# * https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/v2_Annotations_Val_mscoco.zip

# %%
# import libraries
import json
from collections import Counter
import csv
import nltk

nltk.download('wordnet')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %% [markdown]
# # train dataset visualization data creation

# %%
# training question json
train_qn_file = "VQA2/v2_OpenEnded_mscoco_train2014_questions.json"
with open(train_qn_file) as fs:
    train_qns = json.load(fs)

# training answers json
train_ans_file = "VQA2/v2_mscoco_train2014_annotations.json"
with open(train_ans_file) as fs:
    train_ans = json.load(fs)
    print(train_ans["annotations"][:10])
# Out:
# [{'question_type': 'what is this', 'multiple_choice_answer': 'net', 'answers': [{'answer': 'net', 'answer_confidence': 'maybe', 'answer_id': 1}, {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 2}, {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 3}, {'answer': 'netting', 'answer_confidence': 'yes', 'answer_id': 4}, {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 5}, {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 6}, {'answer': 'mesh', 'answer_confidence': 'maybe', 'answer_id': 7}, {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 8}, {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 9}, {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 10}], 'image_id': 458752, 'answer_type': 'other', 'question_id': 458752000}, {'question_type': 'what', 'multiple_choice_answer': 'pitcher', 'answers': [{'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 1}, {'answer': 'catcher', 'answer_confidence': 'no', 'answer_id': 2}, {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 3}, {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 4}, {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 5}, {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 6}, {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 7}, {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 8}, {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 9}, {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 10}], 'image_id': 458752, 'answer_type': 'other', 'question_id': 458752001}, {'answer_type': 'other', 'multiple_choice_answer': 'orange', 'answers': [{'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 1}, {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 2}, {'answer': 'orange', 'answer_confidence': 'maybe', 'answer_id': 3}, {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 4}, {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 5}, {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 6}, {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 7}, {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 8}, {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 9}, {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 10}], 'image_id': 458752, 'question_type': 'what color is the', 'question_id': 458752002}, {'question_type': 'is this', 'multiple_choice_answer': 'yes', 'answers': [{'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 1}, {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 2}, {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 3}, {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 4}, {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 5}, {'answer': 'no', 'answer_confidence': 'maybe', 'answer_id': 6}, {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 7}, {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 8}, {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 9}, {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 10}], 'image_id': 458752, 'answer_type': 'yes/no', 'question_id': 458752003}, {'question_type': 'what color is the', 'multiple_choice_answer': 'white', 'answers': [{'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 1}, {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 2}, {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 3}, {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 4}, {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 5}, {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 6}, {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 7}, {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 8}, {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 9}, {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 10}], 'image_id': 262146, 'answer_type': 'other', 'q ...

# %%
# get the number of yes/no questions and their respective questions
# according to answer json

train_yes_no_qn_ids = []
train_total_yes_no = 0
train_yes_num = 0
train_no_num = 0
for ans in train_ans["annotations"]:
    if ans["answer_type"] == "yes/no":   # yes/no questions
        train_total_yes_no += 1
        train_yes_no_qn_ids.append(ans["question_id"])   # save ids
        if ans["multiple_choice_answer"] == "yes":
            train_yes_num += 1
        else:
            train_no_num += 1
print("Training set, number of yes/no questions:", train_total_yes_no)
print("Num of yes answer questions: ", train_yes_num)
print("Num of no answer questions: ", train_no_num)
# Out:
# Training set, number of yes/no questions: 166882
# Num of yes answer questions:  84615
# Num of no answer questions:  82267

# %%
# get all the question strings corresponding to yes/no answers
train_yes_no_ids = set(train_yes_no_qn_ids)

train_yes_no_qn = 0
train_qn_word_list = []
for qn in train_qns["questions"]:
    if qn["question_id"] in train_yes_no_ids:
        train_yes_no_qn += 1
        train_qn_word_list.extend([i.lower() for i in qn["question"][:-1].split(" ")])

print(train_qn_word_list[:100])
print("number of yes no questions: ", train_yes_no_qn)

train_joined_string = " ".join(train_qn_word_list)
train_cleaned_list = nltk.word_tokenize(train_joined_string)
train_counts = Counter(train_cleaned_list)
train_sort_wc = sorted(train_counts.items(), key=lambda x: x[1], reverse=True)
print(train_sort_wc)
# Out:
# ['is', 'this', 'man', 'a', 'professional', 'baseball', 'player', 'is', 'the', 'dog', 'waiting', 'is', 'the', 'sky', 'blue', 'is', 'there', 'snow', 'on', 'the', 'mountains', 'is', 'the', 'window', 'open', 'is', 'she', 'brushing', 'is', 'the', 'man', 'smiling', 'does', 'his', 'tie', 'pair', 'well', 'with', 'his', 'suit', 'does', 'the', 'man', 'look', 'happy', 'is', 'this', 'photo', 'in', 'color', 'is', 'the', 'man', 'wearing', 'a', 'plain', 'tie', 'judging', 'from', 'the', 'dress,', 'was', 'this', 'taken', 'in', 'a', 'latin', 'american', 'country', 'are', 'the', 'men', 'on', 'the', 'sidewalk', 'was', 'this', 'photo', 'taken', 'recently', 'does', 'the', 'guy', 'have', 'a', 'tattoo', 'is', 'the', "man's", 'visor', 'providing', 'his', 'face', 'enough', 'protection', 'is', 'the', 'man', 'riding', 'on']
# number of yes no questions:  166882
# [('is', 106957), ('the', 104045), ('a', 49931), ('this', 48579), ('are', 32034), ('in', 26122), ('there', 25376), ('on', 17285), ('does', 11596), ('man', 9109), ('of', 8814), ('it', 8420), ('to', 8371), ('these', 7611), ('wearing', 7329), ('have', 6767), ('picture', 6662), ('any', 5626), ('people', 5380), ('person', 5010), ('do', 4972), ('you', 4690), ('photo', 4460), ('an', 4301), ('be', 4038), ('they', 3572), ('woman', 3406), ('he', 3307), ('for', 3182), ('look', 3150), ("'s", 3146), ('can', 3124), ('that', 3081), ('water', 3035), ('all', 2866), ('dog', 2832), ('room', 2782), ('at', 2751), ('cat', 2675), ('see', 2660), ('train', 2597), ('same', 2456), ('animals', 2243), ('food', 2153), ('animal', 2099), ('has', 1982), ('taken', 1904), ('plane', 1858), ('pizza', 1836), ('bus', 1805), ('color', 1791), ('could', 1755), ('day', 1729), ('like', 1727), ('one', 1720), ('would', 1710), ('and', 1685), ('was', 1642), ('sky', 1631), ('someone', 1626), ('she', 1598), ('his', 1596), ('going', 1519), ('with', 1515), ('been', 1489), ('white', 1431), ('happy', 1430), ('street', 1412), ('both', 1411), ('did', 1393), ('toilet', 1388), ('sunny', 1388), ('boy', 1364), ('bathroom', 1362), ('anyone', 1343), ('ground', 1338), ('than', 1325), ('table', 1314), ('girl', 1312), ('image', 1287), ('eating', 1277), ('bear', 1235), ('ball', 1213), ('giraffe', 1194), ('child', 1186), ('elephant', 1173), ('open', 1171), ('clean', 1162), ('up', 1160), ('meal', 1152), ('trees', 1150), ('playing', 1126), ('standing', 1122), ('here', 1099), ('out', 1079), ('from', 1074), ('sign', 1071), ('kitchen', 1061), ('plate', 1059), ('black', 1054), ('horse', 1047), ('background', 1047), ('outside', 1046), ('grass', 1044), ('men', 1036), ('bed', 1017), ('glasses', 1010), ('looking', 1007), ('moving', 1001), ('clouds', 997), ('real', 986), ('sitting', 982), ('made', 978), ('appear', 977), ('snow', 964), ('car', 956), ('shirt', 951), ('bird', 949), ('eat', 948), ('will', 921), ('more', 912), ('light', 911), ('scene', 906), ('hair', 906), ('two', 895), ('building', 891), ('raining', 890), ('truck', 883), ('healthy', 881), ('visible', 881), ('baby', 874), ('hat', 871), ('window', 868), ('time', 854), ('clock', 848), ('her', 847), ('bike', 832), ('their', 829), ('red', 820), ('holding', 813), ('cold', 808), ('area', 806), ('down', 804), ('camera', 802), ('full', 796), ('being', 796), ('boat', 793), ('beach', 793), ('right', 793), ('good', 792), ('lights', 787), ('computer', 785), ('wild', 777), ('game', 768), ('old', 766), ('phone', 752), ('road', 752), ('green', 748), ('giraffes', 737), ('new', 737), ('flowers', 733), ('cake', 731), ('other', 710), ('wall', 710), ('guy', 698), ('floor', 698), ('tv', 695), ('tree', 693), ('zebra', 690), ('need', 687), ('clear', 686), ('daytime', 684), ('blue', 683), ('by', 675), ('player', 666), ('flying', 666), ('cloudy', 666), ('elephants', 664), ('lot', 656), ('place', 656), ('zoo', 646), ('park', 643), ('cars', 639), ('tennis', 638), ('laptop', 637), ('bench', 622), ('something', 620), ('riding', 614), ('city', 612), ('hot', 610), ('professional', 608), ('modern', 605), ('match', 602), ('sleeping', 597), ('fence', 588), ('sun', 577), ('facing', 576), ('home', 575), ('left', 574), ('about', 572), ('motion', 565), ('night', 564), ('hit', 563), ('those', 561), ('shoes', 559), ('zebras', 557), ('having', 553), ('horses', 546), ('sandwich', 544), ('restaurant', 542), ('fire', 541), ('door', 537), ('motorcycle', 536), ('smiling', 527), ('fruit', 522), ('skiing', 521), ('likely', 515), ('birds', 513), ('mirror', 511), ('walking', 510), ('lady', 510), ('bananas', 505), ('running', 505), ('off', 504), ('sheep', 503), ('glass', 500), ('air', 498), ('tie', 496), ('inside', 496), ('each', 495), ('ready', 495), ('umbrella', 492), ('vehicle', 491), ('skateboard', 491), ('wet', 482), ('get', 479), ('natural', 479), ('near', 478), ('think', 478), ('large', 477), ('big', 472), ('as', 472), ('top', 472), ('house', 471), ('taking', 469), ('used', 469), ('hel ...

# %%
# save word count to csv file
with open('train_word_count.csv', 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for word in train_sort_wc:
        spamwriter.writerow([word[0], word[1]])

# %%
# get part of speecg tag
train_pos = nltk.pos_tag(list(train_counts.keys()))
print(train_pos)
# Out:
# [('is', 'VBZ'), ('this', 'DT'), ('man', 'NN'), ('a', 'DT'), ('professional', 'JJ'), ('baseball', 'NN'), ('player', 'NN'), ('the', 'DT'), ('dog', 'NN'), ('waiting', 'VBG'), ('sky', 'JJ'), ('blue', 'NN'), ('there', 'RB'), ('snow', 'VBZ'), ('on', 'IN'), ('mountains', 'NNS'), ('window', 'JJ'), ('open', 'JJ'), ('she', 'PRP'), ('brushing', 'VBG'), ('smiling', 'VBG'), ('does', 'VBZ'), ('his', 'PRP$'), ('tie', 'NN'), ('pair', 'NN'), ('well', 'RB'), ('with', 'IN'), ('suit', 'NN'), ('look', 'VBP'), ('happy', 'JJ'), ('photo', 'NN'), ('in', 'IN'), ('color', 'NN'), ('wearing', 'NN'), ('plain', 'NN'), ('judging', 'NN'), ('from', 'IN'), ('dress', 'NN'), (',', ','), ('was', 'VBD'), ('taken', 'VBN'), ('latin', 'JJ'), ('american', 'JJ'), ('country', 'NN'), ('are', 'VBP'), ('men', 'NNS'), ('sidewalk', 'RBR'), ('recently', 'RB'), ('guy', 'NNS'), ('have', 'VBP'), ('tattoo', 'VBN'), ("'s", 'POS'), ('visor', 'NN'), ('providing', 'VBG'), ('face', 'NN'), ('enough', 'JJ'), ('protection', 'NN'), ('riding', 'VBG'), ('dirt', 'JJ'), ('path', 'NN'), ('walls', 'NNS'), ('done', 'VBN'), ('summery', 'NN'), ('curtain', 'NN'), ('patterned', 'VBD'), ('windows', 'NNS'), ('same', 'JJ'), ('size', 'NN'), ('shadow', 'NN'), ('of', 'IN'), ('tree', 'JJ'), ('foreground', 'NN'), ('did', 'VBD'), ('someone', 'NN'), ('forget', 'NN'), ('luggage', 'NN'), ('it', 'PRP'), ('daytime', 'VBZ'), ('person', 'NN'), ('hat', 'WP'), ('collar', 'JJ'), ('clear', 'JJ'), ('day', 'NN'), ('body', 'NN'), ('water', 'NN'), ('here', 'RB'), ('light', 'JJ'), ('room', 'NN'), ('messy', 'JJ'), ('tv', 'NN'), ('screen', 'NN'), ('laptop', 'JJ'), ('image', 'NN'), ('animal', 'NN'), ('mammal', 'JJ'), ('rocks', 'NNS'), ('picture', 'NN'), ('has', 'VBZ'), ('sheep', 'RB'), ('been', 'VBN'), ('shaved', 'VBN'), ('three', 'CD'), ('having', 'VBG'), ('good', 'JJ'), ('time', 'NN'), ('could', 'MD'), ('be', 'VB'), ('zoo', 'JJ'), ('animals', 'NNS'), ('eating', 'VBG'), ('zebra', 'NN'), ('giraffe', 'NN'), ('both', 'DT'), ('giraffes', 'VBP'), ('standing', 'VBG'), ('they', 'PRP'), ('at', 'IN'), ('some', 'DT'), ('trees', 'NNS'), ('dead', 'VBP'), ('any', 'DT'), ('shade', 'NN'), ('these', 'DT'), ('living', 'VBG'), ('free', 'JJ'), ('range', 'NN'), ('rock', 'NN'), ('near', 'IN'), ('moving', 'VBG'), ('angry', 'JJ'), ('flowers', 'NNS'), ('vase', 'VBP'), ('all', 'DT'), ('white', 'JJ'), ('foot', 'NN'), ('likely', 'RB'), ('do', 'VBP'), ('gentleman', 'JJ'), ('socks', 'NNS'), ('match', 'NN'), ('shoes', 'NNS'), ('and', 'CC'), ('belt', 'NN'), ('zebras', 'NNS'), ('facing', 'VBG'), ('direction', 'NN'), ('horse', 'NN'), ('drinking', 'VBG'), ('wine', 'JJ'), ('child', 'NN'), ('party', 'NN'), ('glasses', 'NNS'), ('dessert', 'VBP'), ('those', 'DT'), ('kites', 'NNS'), ('air', 'VBP'), ('hot', 'JJ'), ('ketchup', 'NN'), ('grilled', 'VBD'), ('you', 'PRP'), ('tried', 'VBN'), ('like', 'IN'), ('before', 'IN'), ('toy-sized', 'JJ'), ('truck', 'NN'), ('carpet', 'NN'), ('floor', 'NN'), ('plane', 'NN'), ('landing', 'VBG'), ('taking', 'VBG'), ('off', 'RP'), ('airliners', 'NNS'), ('cargo', 'VBP'), ('planes', 'NNS'), ('bear', 'IN'), ('normal', 'JJ'), ('flower', 'NN'), ('arrangement', 'NN'), ('lawn', 'NN'), ('playing', 'VBG'), ('polo', 'JJ'), ('reading', 'NN'), ('cell', 'NN'), ('phone', 'NN'), ('stop', 'NN'), ('sign', 'NN'), ('unhappy', 'JJ'), ('going', 'VBG'), ('to', 'TO'), ('share', 'NN'), ('bananas', 'NNS'), ('painted', 'VBD'), ('real', 'JJ'), ('ones', 'NNS'), ('will', 'MD'), ('birds', 'VB'), ('go', 'VB'), ('into', 'IN'), ('bird', 'NN'), ('afraid', 'JJ'), ('ledge', 'NN'), ('high', 'JJ'), ('front', 'JJ'), ('television', 'NN'), ('under', 'IN'), ('armchairs', 'NNS'), ('for', 'IN'), ('cat', 'NN'), ('hide', 'NN'), ('numbers', 'NNS'), ('clock', 'VBP'), ('big', 'JJ'), ('behind', 'IN'), ('wedding', 'VBG'), ('crust', 'NN'), ('burnt', 'NN'), ('pizza', 'NN'), ('deep', 'JJ'), ('dish', 'NN'), ('banana', 'NN'), ('freshly', 'RB'), ('peeled', 'VBD'), ('closed', 'VBD'), ('show', 'NN'), ('train', 'NN'), ('tracks', 'NNS'), ('work', 'VBP'), ('3', 'CD'), ('elephants', 'NNS'), ('full' ...

# %%
# find verb, noun, adjective, spatial prepersation
spatial_prep_word = [
                "above", "across", "around","behind", "beside", "down", 
                "from", "in", "inside", "into", "near", "next", "on", "out", 
                "outside", "over", "through", "under", "up", "with"
              ]
train_verb = {}
train_noun = {}
train_adjective = {}
train_spatial_prep = {}

for word in train_pos:
    if word[0] in spatial_prep_word:
        train_spatial_prep[word[0]] = train_counts[word[0]]
        continue
    if word[1].startswith("J"):
        train_adjective[word[0]] = train_counts[word[0]]
        continue
    if word[1].startswith("NN"):
        train_noun[word[0]] = train_counts[word[0]]
        continue
    if word[1].startswith("VB"):
        train_verb[word[0]] = train_counts[word[0]]
        continue

# %%
# sort part of speech wourd count dictionaries
train_verb_sort_wc = sorted(train_verb.items(), key=lambda x: x[1], reverse=True)
train_adjective_sort_wc = sorted(train_adjective.items(), key=lambda x: x[1], reverse=True)
train_noun_sort_wc = sorted(train_noun.items(), key=lambda x: x[1], reverse=True)
train_spatial_prep_sort_wc = sorted(train_spatial_prep.items(), key=lambda x: x[1], reverse=True)
train_spatial_prep_sort_wc
# Out:
# [('in', 26122),
#  ('on', 17285),
#  ('with', 1515),
#  ('up', 1160),
#  ('out', 1079),
#  ('from', 1074),
#  ('outside', 1046),
#  ('down', 804),
#  ('inside', 496),
#  ('near', 478),
#  ('behind', 467),
#  ('over', 413),
#  ('next', 362),
#  ('under', 346),
#  ('around', 315),
#  ('into', 309),
#  ('through', 288),
#  ('above', 187),
#  ('across', 62),
#  ('beside', 54)]

# %%
# save sorted part of speech result to csv

# verb
with open('train_word_count_verb.csv', 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for word in train_verb_sort_wc:
        spamwriter.writerow([word[0], word[1]])

# noun
with open('train_word_count_noun.csv', 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for word in train_noun_sort_wc:
        spamwriter.writerow([word[0], word[1]])

# adjective
with open('train_word_count_adj.csv', 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for word in train_adjective_sort_wc:
        spamwriter.writerow([word[0], word[1]])

# prepersation
with open('train_word_count_prep.csv', 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for word in train_spatial_prep_sort_wc:
        spamwriter.writerow([word[0], word[1]])

# %% [markdown]
# # validation set dataset visualization data creation

# %%
# val question json
val_qn_file = "VQA2/v2_OpenEnded_mscoco_val2014_questions.json"
with open(val_qn_file) as fs:
    val_qns = json.load(fs)

# val answer json
val_ans_file = "VQA2/v2_mscoco_val2014_annotations.json"
with open(val_ans_file) as fs:
    val_ans = json.load(fs)
    print(train_ans["annotations"][:10])
# Out:
# [{'question_type': 'what is this', 'multiple_choice_answer': 'net', 'answers': [{'answer': 'net', 'answer_confidence': 'maybe', 'answer_id': 1}, {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 2}, {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 3}, {'answer': 'netting', 'answer_confidence': 'yes', 'answer_id': 4}, {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 5}, {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 6}, {'answer': 'mesh', 'answer_confidence': 'maybe', 'answer_id': 7}, {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 8}, {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 9}, {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 10}], 'image_id': 458752, 'answer_type': 'other', 'question_id': 458752000}, {'question_type': 'what', 'multiple_choice_answer': 'pitcher', 'answers': [{'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 1}, {'answer': 'catcher', 'answer_confidence': 'no', 'answer_id': 2}, {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 3}, {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 4}, {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 5}, {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 6}, {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 7}, {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 8}, {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 9}, {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 10}], 'image_id': 458752, 'answer_type': 'other', 'question_id': 458752001}, {'answer_type': 'other', 'multiple_choice_answer': 'orange', 'answers': [{'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 1}, {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 2}, {'answer': 'orange', 'answer_confidence': 'maybe', 'answer_id': 3}, {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 4}, {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 5}, {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 6}, {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 7}, {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 8}, {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 9}, {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 10}], 'image_id': 458752, 'question_type': 'what color is the', 'question_id': 458752002}, {'question_type': 'is this', 'multiple_choice_answer': 'yes', 'answers': [{'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 1}, {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 2}, {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 3}, {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 4}, {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 5}, {'answer': 'no', 'answer_confidence': 'maybe', 'answer_id': 6}, {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 7}, {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 8}, {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 9}, {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 10}], 'image_id': 458752, 'answer_type': 'yes/no', 'question_id': 458752003}, {'question_type': 'what color is the', 'multiple_choice_answer': 'white', 'answers': [{'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 1}, {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 2}, {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 3}, {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 4}, {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 5}, {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 6}, {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 7}, {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 8}, {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 9}, {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 10}], 'image_id': 262146, 'answer_type': 'other', 'q ...

# %%
# get the number of yes/no questions and their respective questions
# according to answer json

val_yes_no_qn_ids = []
val_total_yes_no = 0
val_yes_num = 0
val_no_num = 0
for ans in val_ans["annotations"]:
    if ans["answer_type"] == "yes/no":
        val_total_yes_no += 1
        val_yes_no_qn_ids.append(ans["question_id"])
        if ans["multiple_choice_answer"] == "yes":
            val_yes_num += 1
        else:
            val_no_num += 1
print("Training set, number of yes/no questions:", val_total_yes_no)
print("Num of yes answer questions: ", val_yes_num)
print("Num of no answer questions: ", val_no_num)
# Out:
# Training set, number of yes/no questions: 80541
# Num of yes answer questions:  40585
# Num of no answer questions:  39956

# %%
# get all the question strings corresponding to yes/no answers
val_yes_no_ids = set(val_yes_no_qn_ids)
val_yes_no_qn = 0
val_qn_word_list = []
for qn in val_qns["questions"]:
    if qn["question_id"] in val_yes_no_ids:
        val_yes_no_qn += 1
        val_qn_word_list.extend([i.lower() for i in qn["question"][:-1].split(" ")])

print(val_qn_word_list[:100])
print(val_yes_no_qn)

val_joined_string = " ".join(val_qn_word_list)
val_cleaned_list = nltk.word_tokenize(val_joined_string)
val_counts = Counter(val_cleaned_list)
val_sort_wc = sorted(val_counts.items(), key=lambda x: x[1], reverse=True)

print(val_sort_wc)
# Out:
# ['is', 'this', 'a', 'creamy', 'soup', 'is', 'this', 'rice', 'noodle', 'soup', 'is', 'it', 'daylight', 'in', 'this', 'picture', 'did', 'the', 'batter', 'hit', 'the', 'ball', 'is', 'there', 'a', 'chain', 'link', 'fence', 'in', 'the', 'image', 'is', 'the', 'boy', 'playing', 'baseball', 'is', 'that', 'a', 'folding', 'chair', 'are', 'these', 'twin', 'mattresses', 'is', 'this', 'room', 'decorated', 'for', 'the', '1970s', 'are', 'the', 'lights', 'on', 'in', 'this', 'room', 'are', 'the', 'windows', 'big', 'is', 'this', 'room', 'in', "someone's", 'home', 'is', 'the', 'bed', 'white', 'could', 'this', 'be', 'a', 'hotel', 'room', 'is', 'the', 'bed', 'made', 'are', 'there', 'bed', 'headboards', 'present', 'in', 'the', 'photo', 'is', 'there', 'a', 'mirror', 'in', 'the', 'room', 'is', 'the']
# 80541
# [('is', 51373), ('the', 50710), ('a', 23966), ('this', 23126), ('are', 15219), ('in', 12061), ('there', 12052), ('on', 8357), ('does', 6123), ('man', 4638), ('of', 4321), ('to', 4184), ('it', 4183), ('these', 3674), ('have', 3575), ('wearing', 3392), ('picture', 2992), ('any', 2687), ('people', 2470), ('do', 2232), ('person', 2205), ('you', 2138), ('an', 2031), ('photo', 1951), ('woman', 1700), ('be', 1698), ('look', 1698), ('water', 1654), ('can', 1647), ("'s", 1589), ('they', 1543), ('for', 1532), ('he', 1522), ('that', 1507), ('at', 1491), ('cat', 1463), ('all', 1414), ('train', 1348), ('room', 1318), ('dog', 1293), ('same', 1256), ('see', 1120), ('animals', 1056), ('food', 1000), ('has', 997), ('animal', 932), ('one', 922), ('like', 910), ('someone', 907), ('pizza', 894), ('taken', 890), ('bus', 872), ('going', 825), ('would', 817), ('was', 804), ('his', 800), ('color', 789), ('she', 789), ('been', 763), ('with', 750), ('boy', 736), ('day', 729), ('toilet', 727), ('and', 726), ('girl', 724), ('did', 715), ('sky', 683), ('happy', 671), ('could', 662), ('than', 647), ('sunny', 643), ('plane', 641), ('bathroom', 634), ('here', 630), ('giraffe', 628), ('street', 625), ('anyone', 608), ('from', 605), ('bear', 604), ('eating', 603), ('both', 596), ('ball', 583), ('open', 579), ('ground', 570), ('up', 568), ('meal', 568), ('looking', 565), ('will', 564), ('table', 564), ('trees', 562), ('elephant', 559), ('moving', 557), ('out', 555), ('child', 544), ('playing', 540), ('plate', 534), ('white', 532), ('kitchen', 531), ('men', 527), ('clean', 508), ('sitting', 506), ('two', 503), ('standing', 499), ('horse', 493), ('building', 487), ('car', 487), ('scene', 484), ('grass', 478), ('outside', 478), ('real', 477), ('eat', 463), ('cold', 459), ('background', 457), ('bird', 455), ('sign', 454), ('light', 451), ('good', 451), ('made', 446), ('truck', 445), ('boat', 443), ('bed', 442), ('more', 442), ('raining', 438), ('bike', 437), ('shirt', 437), ('area', 436), ('hair', 434), ('clock', 427), ('her', 425), ('full', 423), ('road', 421), ('healthy', 415), ('window', 414), ('right', 411), ('beach', 411), ('red', 407), ('black', 407), ('being', 404), ('baby', 399), ('camera', 399), ('glasses', 399), ('snow', 397), ('clouds', 396), ('old', 394), ('other', 393), ('holding', 393), ('flowers', 387), ('appear', 386), ('lights', 385), ('green', 378), ('zoo', 375), ('zebra', 373), ('down', 371), ('lot', 370), ('game', 370), ('visible', 364), ('phone', 358), ('cake', 354), ('computer', 354), ('time', 352), ('elephants', 352), ('new', 351), ('tree', 348), ('wall', 346), ('player', 344), ('place', 342), ('need', 342), ('riding', 337), ('city', 337), ('clear', 336), ('cloudy', 336), ('something', 336), ('blue', 333), ('bench', 331), ('wild', 328), ('cars', 323), ('hat', 323), ('about', 322), ('tv', 321), ('home', 318), ('hot', 312), ('their', 310), ('left', 306), ('guy', 304), ('likely', 304), ('shoes', 304), ('sun', 304), ('floor', 301), ('sheep', 301), ('park', 300), ('hit', 296), ('image', 293), ('fence', 291), ('match', 289), ('those', 287), ('by', 287), ('tie', 284), ('wet', 283), ('helmet', 282), ('flying', 281), ('house', 280), ('professional', 276), ('giraffes', 275), ('facing', 272), ('sandwich', 272), ('having', 271), ('get', 270), ('umbrella', 270), ('inside', 268), ('glass', 265), ('zebras', 264), ('running', 263), ('ready', 261), ('tennis', 260), ('dressed', 258), ('door', 257), (',', 254), ('sleeping', 254), ('mirror', 253), ('birds', 251), ('modern', 251), ('motorcycle', 250), ('women', 250), ('each', 249), ('top', 247), ('near', 247), ('over', 247), ('as', 246), ('big', 245), ('fall', 245), ('skateboard', 241), ('night', 240), ('air', 239), ('anything', 238), ('used', 237), ('leaves', 237), ('daytime', 236), ('children', 236), ('behind', 235), ('fire', 234), ('kite', 233), ('vehicle', 232), ('way', 230), ('laptop', 229), ('front', 227), ('stop', 226), ('cows', 226), ('taking', 225), ('safe', 224), ('vase', 222), ('high', 222), ('surfer', ...

# %%
# save word count to csv file
with open('val_word_count.csv', 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for word in val_sort_wc:
        spamwriter.writerow([word[0], word[1]])

# %%
# get part of speech tag
val_pos = nltk.pos_tag(list(val_counts.keys()))
print(val_pos)
# Out:
# [('is', 'VBZ'), ('this', 'DT'), ('a', 'DT'), ('creamy', 'JJ'), ('soup', 'NN'), ('rice', 'NN'), ('noodle', 'IN'), ('it', 'PRP'), ('daylight', 'VBD'), ('in', 'IN'), ('picture', 'NN'), ('did', 'VBD'), ('the', 'DT'), ('batter', 'NN'), ('hit', 'VBD'), ('ball', 'RB'), ('there', 'RB'), ('chain', 'NN'), ('link', 'NN'), ('fence', 'NN'), ('image', 'NN'), ('boy', 'VBD'), ('playing', 'VBG'), ('baseball', 'NN'), ('that', 'IN'), ('folding', 'VBG'), ('chair', 'NN'), ('are', 'VBP'), ('these', 'DT'), ('twin', 'JJ'), ('mattresses', 'NNS'), ('room', 'NN'), ('decorated', 'VBN'), ('for', 'IN'), ('1970s', 'CD'), ('lights', 'NNS'), ('on', 'IN'), ('windows', 'NNS'), ('big', 'JJ'), ('someone', 'NN'), ("'s", 'POS'), ('home', 'NN'), ('bed', 'NN'), ('white', 'JJ'), ('could', 'MD'), ('be', 'VB'), ('hotel', 'VBN'), ('made', 'VBN'), ('headboards', 'NNS'), ('present', 'JJ'), ('photo', 'JJ'), ('mirror', 'NN'), ('desk', 'NN'), ('cluttered', 'VBN'), ('has', 'VBZ'), ('been', 'VBN'), ('any', 'DT'), ('boxes', 'JJ'), ('multi-purpose', 'NN'), ('will', 'MD'), ('kid', 'VB'), ('leave', 'VB'), ('powdered', 'VBN'), ('sugar', 'NN'), ('his', 'PRP$'), ('face', 'NN'), ('person', 'NN'), ('wearing', 'VBG'), ('tie', 'JJ'), ('man', 'NN'), ('purple', 'NN'), ('designer', 'NN'), ('color', 'NN'), ('drainage', 'NN'), ('pic', 'NN'), ('red', 'VBD'), ('sandal', 'NN'), ('here', 'RB'), ('players', 'NNS'), ('dugout', 'VBP'), ('battery', 'NN'), ('looking', 'VBG'), ('at', 'IN'), ('can', 'MD'), ('you', 'PRP'), ('turn', 'VB'), ('right', 'JJ'), ('or', 'CC'), ('left', 'JJ'), ('tunnel', 'NN'), ('tree', 'JJ'), ('front', 'NN'), ('of', 'IN'), ('building', 'VBG'), ('riding', 'VBG'), ('bike', 'NN'), ('two', 'CD'), ('buildings', 'NNS'), ('hospital', 'NN'), ('still', 'RB'), ('snowing', 'VBG'), ('does', 'VBZ'), ('appear', 'VB'), ('to', 'TO'), ('multiple', 'VB'), ('exposures', 'NNS'), ('black', 'JJ'), ('clad', 'JJ'), ('snowboarder', 'NN'), ('an', 'DT'), ('adult', 'NN'), ('party', 'NN'), ('see', 'NN'), ('hook', 'VBD'), ('up', 'RP'), ('train', 'NN'), ('station', 'NN'), ('smoke', 'VBD'), ('coming', 'VBG'), ('out', 'RP'), ('rural', 'JJ'), ('setting', 'VBG'), ('tracks', 'NNS'), ('clear', 'JJ'), ('tour', 'NN'), ('buses', 'NNS'), ('all', 'DT'), ('three', 'CD'), ('cars', 'NNS'), ('facing', 'VBG'), ('same', 'JJ'), ('direction', 'NN'), ('lot', 'NN'), ('people', 'NNS'), ('milling', 'VBG'), ('around', 'RB'), ('large', 'JJ'), ('rain', 'NN'), ('cake', 'VBP'), ('one', 'CD'), ('way', 'NN'), ('street', 'NN'), ('giraffe', 'JJ'), ('baby', 'NN'), ('animals', 'NNS'), ('shade', 'VBD'), ('wild', 'JJ'), ('giraffes', 'NN'), ('eating', 'VBG'), ('grass', 'NN'), ('dinner', 'NN'), ('do', 'VBP'), ('body', 'NN'), ('water', 'NN'), ('beach', 'VBP'), ('scene', 'NN'), ('snowboarding', 'VBG'), ('snow', 'JJ'), ('trees', 'NNS'), ('flying', 'VBG'), ('off', 'RP'), ('ski', 'JJ'), ('slope', 'NN'), ('he', 'PRP'), ('going', 'VBG'), ('land', 'NN'), ('have', 'VBP'), ('goggles', 'NNS'), ('dog', 'VBP'), ('collar', 'JJ'), ('wetsuit', 'NN'), ('wet', 'NN'), ('pill', 'NN'), ('bottles', 'VBZ'), ('computer', 'NN'), ('popular', 'JJ'), ('model', 'NN'), ('comfortable', 'JJ'), ('chairs', 'NNS'), ('girls', 'NNS'), ('professionals', 'NNS'), ('bear', 'VBP'), ('real', 'JJ'), ('dogs', 'NNS'), ('enjoy', 'VBP'), ('tennis', 'RB'), ('tired', 'VBN'), ('court', 'NN'), ('blue', 'NN'), ('doubles', 'VBZ'), ('both', 'DT'), ('men', 'NNS'), ('hats', 'VBP'), ('professional', 'JJ'), ('bread', 'NN'), ('look', 'VBP'), ('like', 'IN'), ('healthy', 'JJ'), ('meal', 'NN'), ('silver', 'VB'), ('new', 'JJ'), ('bright', 'JJ'), ('green', 'JJ'), ('container', 'NN'), ('ground', 'NN'), ('blocking', 'VBG'), ('motorcycle', 'NN'), ('travel', 'NN'), ('often', 'RB'), ('propped', 'VBD'), ('motorbikes', 'NNS'), ('size', 'NN'), ('light', 'JJ'), ('time', 'NN'), ('correct', 'JJ'), ('overcast', 'RB'), ('day', 'NN'), ('low', 'JJ'), ('tide', 'RB'), ('palm', 'VBP'), ('board', 'NN'), ('cloudy', 'NN'), ('girl', 'VBD'), ('sitting', 'VBG'), ('horse', 'NN'), ('correctly', 'RB'), ('english', 'JJ'), ('saddle', 'NN') ...

# %%
# find verb, noun, adjective, spatial prepersation
spatial_prep_word = [
                "above", "across", "around","behind", "beside", "down", 
                "from", "in", "inside", "into", "near", "next", "on", "out", 
                "outside", "over", "through", "under", "up", "with"
              ]
val_verb = {}
val_noun = {}
val_adjective = {}
val_spatial_prep = {}

for word in val_pos:
    if word[0] in spatial_prep_word:
        val_spatial_prep[word[0]] = val_counts[word[0]]
        continue
    if word[1].startswith("J"):
        val_adjective[word[0]] = val_counts[word[0]]
        continue
    if word[1].startswith("NN"):
        val_noun[word[0]] = val_counts[word[0]]
        continue
    if word[1].startswith("VB"):
        val_verb[word[0]] = val_counts[word[0]]
        continue

# %%
# sort the part of speech word count dictionary
val_verb_sort_wc = sorted(val_verb.items(), key=lambda x: x[1], reverse=True)
val_adjective_sort_wc = sorted(val_adjective.items(), key=lambda x: x[1], reverse=True)
val_noun_sort_wc = sorted(val_noun.items(), key=lambda x: x[1], reverse=True)
val_spatial_prep_sort_wc = sorted(val_spatial_prep.items(), key=lambda x: x[1], reverse=True)
val_spatial_prep_sort_wc
# Out:
# [('in', 12061),
#  ('on', 8357),
#  ('with', 750),
#  ('from', 605),
#  ('up', 568),
#  ('out', 555),
#  ('outside', 478),
#  ('down', 371),
#  ('inside', 268),
#  ('near', 247),
#  ('over', 247),
#  ('behind', 235),
#  ('under', 184),
#  ('into', 171),
#  ('next', 156),
#  ('through', 146),
#  ('around', 144),
#  ('above', 82),
#  ('across', 30),
#  ('beside', 19)]

# %%
# save sorted part of speech result to csv

# verb
with open('val_word_count_verb.csv', 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for word in val_verb_sort_wc:
        spamwriter.writerow([word[0], word[1]])

# noun
with open('val_word_count_noun.csv', 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for word in val_noun_sort_wc:
        spamwriter.writerow([word[0], word[1]])

# adjective
with open('val_word_count_adj.csv', 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for word in val_adjective_sort_wc:
        spamwriter.writerow([word[0], word[1]])

# prepersation
with open('val_word_count_prep.csv', 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for word in val_spatial_prep_sort_wc:
        spamwriter.writerow([word[0], word[1]])
